# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from torchvision.datasets import CIFAR10

# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed=1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms for validation (no augmentation)
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # Define the transform for training (and data augmentation)

    train_transform = transforms.Compose([
        transforms.RandomHorizontalFlip(),
        transforms.RandomCrop(32, padding=4),
        transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        transforms.RandomRotation(10),
        transforms.ToTensor(),
        normalize,
    ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images if requested
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = next(data_iter)
        # Unnormalize the images for display
        mean = [0.4914, 0.4822, 0.4465]
        std = [0.2023, 0.1994, 0.2010]
        unnorm_images = [unnormalize(img, mean, std) for img in images]
        X = torch.stack(unnorm_images).numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

def unnormalize(img, mean, std):
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img

trainloader, valloader = get_train_valid_loader()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.8117647].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.92156863].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.89411765].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.7647059].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].

# %% [markdown]
# # Convolutional Neural Network Architecture

# %% [markdown]
# Let's first talk about the overall architecture of a CNN and how each dimension evolves after each layer, we'll take as example the first and famous CNN LeNet5 :
# <figure align="center">
#   <img src="https://doimages.nyc3.cdn.digitaloceanspaces.com/010AI-ML/content/images/2021/10/image-17.png" alt="LeNet5 Architecture" width="600">
#   <figcaption>Image credit: <a href="https://en.wikipedia.org">Wikipedia</a></figcaption>
# </figure>

# %% [markdown]
# For that, we will have some quick questions to see if you understand what happens during training/inference:
#
# ### 1. First Layer Convolution
#
# If we consider the input of LeNet5 to be CIFAR-10, what would be the shape of the parameters of the first convolutional layer (stride = 1)?
#
# - **A.** `torch.Size([6, 1, 5, 5])`
# - **B.** `torch.Size([6, 3, 3, 3])`
# - **C.** `torch.Size([6, 1, 5, 5])`
# - **D.** `torch.Size([6, 3, 5, 5])`
#
# ---
#
# Response D., as we have 6 filters of size 5x5 (for the kernel) and the number 3 is for the number of input channels (3 because CIFAR-10 contains RGB images).
#
# ### 2. Subsampling Window
#
# What is the shape of the subsampling window (stride = 2) for the second layer (between C1 and C2), and does this shape remain invariant regardless of the subsampling method (e.g., Avg pooling or Max pooling)?
#
# - **A.** `2x2, yes it does`
# - **B.** `3x3, no it doesn't`
# - **C.** `2x2, no it doesn't`
# - **D.** `yes, it does`
#
# ---
#
# Response A., because we're going from 28x28 to 14x14 so subsampling window is 2x2 and the shape doesn't change between Avg pooling or Max pooling. They only differ in how the value is computed inside the window.
#
# ### 3. Backpropagation for Convolutional Filters
#
# Do the filters in the convolutional layers also benefit from backpropagation?
#
# ---
#
# Yes, The filters in convolutional layers are trainable parameters, so they are updated through backpropagation during training.
#
# ### 4. Role of the Fully-Connected Layer
#
# Explain in your own words why it is necessary to have a fully-connected layer in the architecture.
#
# ---
# Fully-conected layer is used to combine extracted features from the convolutional layers and perform classification. Without it, we cannot perform the classification.
#
# If you had any struggle to answer one of theses questions, feel free to ask a TA about intuition or hints about the solution.

# %% [markdown]
# # Build your own Convolutional Neural Network Architecture

# %% [markdown]
# ## Different ways to improve the accuracy of your network :
# - Change the number of convolutions and layers (you can take inspiration from internet as you as you cite the architecture)
# - Change the optmizer / its hyperparameters
# - Add new types of layers
# - Do some data augmentation in the get_train_valid_loader function (flipped, cropped, uncentered images) cf. https://pytorch.org/vision/stable/transforms.html

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################

        # Convolutional feature extractor
        self.features = nn.Sequential(
            # Block 1
            nn.Conv2d(n_input_channels, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.Conv2d(32, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2,2),

            # Block 2
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2,2),

            # Block 3
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2,2),

            nn.AdaptiveAvgPool2d((1,1))
        )

        # Classifier
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, n_output)
        )

        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ################################################################################
        x = self.features(x)

        # flatten
        x = x.view(x.size(0), -1)

        x = self.classifier(x)

        return x
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        return x

    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.0005, weight_decay=1e-4)

epochs = 5
steps = 0
running_loss = 0
print_every = 20
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):

        steps += 1
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        net.train()

        optimizer.zero_grad()

        output = net(images)
        targets = labels
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        loss = criterion(output, targets)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        loss.backward()
        optimizer.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        running_loss += loss.item()

        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            for ii, (images, labels) in enumerate(valloader):

                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                net.eval()
                with torch.no_grad():
                  outputs = net(images)
                  _, predicted = torch.max(outputs, 1)

                accuracy += (predicted == labels).float().mean()
                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################

            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
            running_loss = 0
            start = time.time()
# Out:
# Epoch: 1/5.. Loss: 2.1878.. Test accuracy: 0.1586.. 0.2869 s/batch
# Epoch: 1/5.. Loss: 2.0345.. Test accuracy: 0.2701.. 0.2730 s/batch
# Epoch: 1/5.. Loss: 1.9406.. Test accuracy: 0.2953.. 0.2428 s/batch
# Epoch: 1/5.. Loss: 1.8415.. Test accuracy: 0.2451.. 0.2833 s/batch
# Epoch: 1/5.. Loss: 1.7883.. Test accuracy: 0.2996.. 0.2429 s/batch
# Epoch: 1/5.. Loss: 1.7448.. Test accuracy: 0.3283.. 0.2899 s/batch
# Epoch: 1/5.. Loss: 1.6607.. Test accuracy: 0.3611.. 0.2425 s/batch
# Epoch: 1/5.. Loss: 1.6658.. Test accuracy: 0.4262.. 0.2892 s/batch
# Epoch: 1/5.. Loss: 1.6371.. Test accuracy: 0.3873.. 0.2434 s/batch
# Epoch: 1/5.. Loss: 1.5876.. Test accuracy: 0.4482.. 0.2898 s/batch
# Epoch: 1/5.. Loss: 1.6448.. Test accuracy: 0.3715.. 0.2414 s/batch
# Epoch: 1/5.. Loss: 1.5840.. Test accuracy: 0.4000.. 0.2926 s/batch
# Epoch: 1/5.. Loss: 1.5390.. Test accuracy: 0.4533.. 0.2410 s/batch
# Epoch: 1/5.. Loss: 1.5650.. Test accuracy: 0.4910.. 0.2969 s/batch
# Epoch: 1/5.. Loss: 1.4655.. Test accuracy: 0.4832.. 0.2415 s/batch
# Epoch: 1/5.. Loss: 1.5062.. Test accuracy: 0.4723.. 0.2908 s/batch
# Epoch: 1/5.. Loss: 1.4960.. Test accuracy: 0.5193.. 0.2417 s/batch
# Epoch: 1/5.. Loss: 1.4532.. Test accuracy: 0.4664.. 0.3068 s/batch
# Epoch: 1/5.. Loss: 1.4140.. Test accuracy: 0.4936.. 0.2415 s/batch
# Epoch: 1/5.. Loss: 1.4211.. Test accuracy: 0.5131.. 0.2991 s/batch
# Epoch: 1/5.. Loss: 1.3641.. Test accuracy: 0.5225.. 0.2388 s/batch
# Epoch: 1/5.. Loss: 1.3658.. Test accuracy: 0.5373.. 0.2922 s/batch
# Epoch: 1/5.. Loss: 1.4125.. Test accuracy: 0.5205.. 0.2404 s/batch
# Epoch: 1/5.. Loss: 1.4153.. Test accuracy: 0.5184.. 0.2910 s/batch
# Epoch: 1/5.. Loss: 1.3268.. Test accuracy: 0.5355.. 0.2388 s/batch
# Epoch: 1/5.. Loss: 1.3761.. Test accuracy: 0.5490.. 0.2898 s/batch
# Epoch: 1/5.. Loss: 1.3466.. Test accuracy: 0.4967.. 0.2423 s/batch
# Epoch: 1/5.. Loss: 1.3342.. Test accuracy: 0.5199.. 0.2914 s/batch
# Epoch: 1/5.. Loss: 1.2789.. Test accuracy: 0.5139.. 0.2392 s/batch
# Epoch: 1/5.. Loss: 1.2849.. Test accuracy: 0.4855.. 0.2929 s/batch
# Epoch: 1/5.. Loss: 1.3557.. Test accuracy: 0.5537.. 0.2450 s/batch
# Epoch: 1/5.. Loss: 1.3362.. Test accuracy: 0.4900.. 0.2988 s/batch
# Epoch: 1/5.. Loss: 1.2875.. Test accuracy: 0.5033.. 0.2437 s/batch
# Epoch: 1/5.. Loss: 1.2760.. Test accuracy: 0.5176.. 0.3146 s/batch
# Epoch: 1/5.. Loss: 1.3162.. Test accuracy: 0.5936.. 0.2484 s/batch
# Epoch: 1/5.. Loss: 1.3120.. Test accuracy: 0.5230.. 0.3046 s/batch
# Epoch: 1/5.. Loss: 1.2160.. Test accuracy: 0.5281.. 0.2401 s/batch
# Epoch: 1/5.. Loss: 1.1934.. Test accuracy: 0.5682.. 0.2923 s/batch
# Epoch: 2/5.. Loss: 1.1763.. Test accuracy: 0.5992.. 0.1957 s/batch
# Epoch: 2/5.. Loss: 1.2718.. Test accuracy: 0.5070.. 0.3025 s/batch
# Epoch: 2/5.. Loss: 1.1714.. Test accuracy: 0.5781.. 0.2336 s/batch
# Epoch: 2/5.. Loss: 1.1936.. Test accuracy: 0.6037.. 0.2943 s/batch
# Epoch: 2/5.. Loss: 1.1622.. Test accuracy: 0.5904.. 0.2355 s/batch
# Epoch: 2/5.. Loss: 1.1980.. Test accuracy: 0.6170.. 0.2943 s/batch
# Epoch: 2/5.. Loss: 1.1956.. Test accuracy: 0.6123.. 0.2593 s/batch
# Epoch: 2/5.. Loss: 1.2190.. Test accuracy: 0.6141.. 0.3149 s/batch
# Epoch: 2/5.. Loss: 1.1360.. Test accuracy: 0.6143.. 0.2655 s/batch
# Epoch: 2/5.. Loss: 1.1701.. Test accuracy: 0.5809.. 0.3340 s/batch
# Epoch: 2/5.. Loss: 1.1335.. Test accuracy: 0.6109.. 0.2585 s/batch
# Epoch: 2/5.. Loss: 1.1502.. Test accuracy: 0.6146.. 0.3282 s/batch
# Epoch: 2/5.. Loss: 1.1769.. Test accuracy: 0.6117.. 0.2652 s/batch
# Epoch: 2/5.. Loss: 1.0790.. Test accuracy: 0.5434.. 0.3252 s/batch
# Epoch: 2/5.. Loss: 1.1733.. Test accuracy: 0.6152.. 0.2616 s/batch
# Epoch: 2/5.. Loss: 1.1261.. Test accuracy: 0.6012.. 0.3027 s/batch
# Epoch: 2/5.. Loss: 1.1697.. Test accuracy: 0.5803.. 0.2486 s/batch
# Epoch: 2/5.. Loss: 1.1509.. Test accuracy: 0.5861.. 0.2832 s/batch
# Epoch: 2/5.. Loss: 1.1364.. Test accuracy: 0.5715.. 0.2573 s/batch
# Epoch: 2/5.. Loss: 1.0871.. Test accuracy: 0.6039.. 0.2713 s/batch
# Epoch: 2/5.. Loss: 1.1472.. Test accuracy: 0.6039.. 0.2708 s/batch
# Epoch: 2/5.. Loss: 1.1199.. Test accuracy: 0.6182.. 0.2657 s/batch
# Epoch: 2/5.. Loss: 1.1414.. Test accuracy: 0.6443.. 0.2738 s/batch
# Epoch: 2/5.. Loss: 1.1289.. Test accuracy: 0.6221.. 0.2539 s/batch
# Epoch: 2/5.. Loss: 1.0850.. Test accuracy: 0.6227.. 0.2833 s/batch
# Epoch: 2/5.. Loss: 1.0807.. Test accuracy: 0.6025.. 0.2475 s/batch
# Epoch: 2/5.. Loss: 1.0760.. Test accuracy: 0.6268.. 0.2838 s/batch
# Epoch: 2/5.. Loss: 1.0686.. Test accuracy: 0.5986.. 0.2452 s/batch
# Epoch: 2/5.. Loss: 1.0600.. Test accuracy: 0.6432.. 0.2908 s/batch
# Epoch: 2/5.. Loss: 1.0716.. Test accuracy: 0.6229.. 0.2488 s/batch
# Epoch: 2/5.. Loss: 1.0965.. Test accuracy: 0.6389.. 0.3167 s/batch
# Epoch: 2/5.. Loss: 1.0447.. Test accuracy: 0.6086.. 0.2486 s/batch
# Epoch: 2/5.. Loss: 1.0434.. Test accuracy: 0.6523.. 0.3344 s/batch
# Epoch: 2/5.. Loss: 1.0884.. Test accuracy: 0.6357.. 0.2584 s/batch
# Epoch: 2/5.. Loss: 1.0412.. Test accuracy: 0.6414.. 0.3243 s/batch
# Epoch: 2/5.. Loss: 1.0688.. Test accuracy: 0.6467.. 0.2600 s/batch
# Epoch: 2/5.. Loss: 1.0581.. Test accuracy: 0.6268.. 0.3285 s/batch
# Epoch: 2/5.. Loss: 1.0474.. Test accuracy: 0.6314.. 0.2503 s/batch
# Epoch: 3/5.. Loss: 1.1367.. Test accuracy: 0.5996.. 0.1449 s/batch
# Epoch: 3/5.. Loss: 1.0743.. Test accuracy: 0.6609.. 0.2529 s/batch
# Epoch: 3/5.. Loss: 0.9788.. Test accuracy: 0.6785.. 0.3157 s/batch
# Epoch: 3/5.. Loss: 0.9932.. Test accuracy: 0.6225.. 0.2505 s/batch
# Epoch: 3/5.. Loss: 1.0529.. Test accuracy: 0.6648.. 0.2928 s/batch
# Epoch: 3/5.. Loss: 1.0278.. Test accuracy: 0.6643.. 0.2584 s/batch
# Epoch: 3/5.. Loss: 1.0116.. Test accuracy: 0.6379.. 0.2715 s/batch
# Epoch: 3/5.. Loss: 0.9981.. Test accuracy: 0.6553.. 0.2785 s/batch
# Epoch: 3/5.. Loss: 1.0289.. Test accuracy: 0.6730.. 0.2542 s/batch
# Epoch: 3/5.. Loss: 1.0366.. Test accuracy: 0.6674.. 0.2793 s/batch
# Epoch: 3/5.. Loss: 0.9970.. Test accuracy: 0.6434.. 0.2557 s/batch
# Epoch: 3/5.. Loss: 0.9648.. Test accuracy: 0.6762.. 0.2909 s/batch
# Epoch: 3/5.. Loss: 0.9800.. Test accuracy: 0.6756.. 0.2531 s/batch
# Epoch: 3/5.. Loss: 1.0500.. Test accuracy: 0.6734.. 0.3075 s/batch
# Epoch: 3/5.. Loss: 1.0017.. Test accuracy: 0.6902.. 0.2597 s/batch
# Epoch: 3/5.. Loss: 0.9785.. Test accuracy: 0.6998.. 0.3211 s/batch
# Epoch: 3/5.. Loss: 1.0323.. Test accuracy: 0.7072.. 0.2534 s/batch
# Epoch: 3/5.. Loss: 0.9558.. Test accuracy: 0.7025.. 0.3253 s/batch
# Epoch: 3/5.. Loss: 1.0085.. Test accuracy: 0.6602.. 0.2560 s/batch
# Epoch: 3/5.. Loss: 0.9674.. Test accuracy: 0.6551.. 0.3219 s/batch
# Epoch: 3/5.. Loss: 1.0394.. Test accuracy: 0.6857.. 0.2533 s/batch
# Epoch: 3/5.. Loss: 0.9492.. Test accuracy: 0.6895.. 0.3216 s/batch
# Epoch: 3/5.. Loss: 0.9305.. Test accuracy: 0.6561.. 0.2520 s/batch
# Epoch: 3/5.. Loss: 0.9153.. Test accuracy: 0.6771.. 0.3189 s/batch
# Epoch: 3/5.. Loss: 0.9817.. Test accuracy: 0.6898.. 0.2530 s/batch
# Epoch: 3/5.. Loss: 0.9396.. Test accuracy: 0.7166.. 0.3122 s/batch
# Epoch: 3/5.. Loss: 0.9725.. Test accuracy: 0.6906.. 0.2550 s/batch
# Epoch: 3/5.. Loss: 0.9423.. Test accuracy: 0.6549.. 0.2939 s/batch
# Epoch: 3/5.. Loss: 0.9192.. Test accuracy: 0.6629.. 0.2551 s/batch
# Epoch: 3/5.. Loss: 0.9046.. Test accuracy: 0.6602.. 0.2882 s/batch
# Epoch: 3/5.. Loss: 0.9629.. Test accuracy: 0.6676.. 0.2720 s/batch
# Epoch: 3/5.. Loss: 0.9393.. Test accuracy: 0.7260.. 0.2655 s/batch
# Epoch: 3/5.. Loss: 0.9371.. Test accuracy: 0.6918.. 0.2792 s/batch
# Epoch: 3/5.. Loss: 0.9684.. Test accuracy: 0.6617.. 0.2498 s/batch
# Epoch: 3/5.. Loss: 0.9478.. Test accuracy: 0.7322.. 0.2794 s/batch
# Epoch: 3/5.. Loss: 0.9716.. Test accuracy: 0.7012.. 0.2466 s/batch
# Epoch: 3/5.. Loss: 0.9366.. Test accuracy: 0.7178.. 0.2850 s/batch
# Epoch: 3/5.. Loss: 0.8572.. Test accuracy: 0.6889.. 0.2440 s/batch
# Epoch: 4/5.. Loss: 0.9295.. Test accuracy: 0.6742.. 0.0788 s/batch
# Epoch: 4/5.. Loss: 0.8783.. Test accuracy: 0.6850.. 0.2438 s/batch
# Epoch: 4/5.. Loss: 0.9304.. Test accuracy: 0.6934.. 0.3078 s/batch
# Epoch: 4/5.. Loss: 0.9517.. Test accuracy: 0.6793.. 0.2494 s/batch
# Epoch: 4/5.. Loss: 0.8600.. Test accuracy: 0.7264.. 0.3308 s/batch
# Epoch: 4/5.. Loss: 0.9429.. Test accuracy: 0.6709.. 0.2576 s/batch
# Epoch: 4/5.. Loss: 0.9093.. Test accuracy: 0.6619.. 0.3226 s/batch
# Epoch: 4/5.. Loss: 0.9092.. Test accuracy: 0.7297.. 0.2505 s/batch
# Epoch: 4/5.. Loss: 0.8795.. Test accuracy: 0.6951.. 0.3265 s/batch
# Epoch: 4/5.. Loss: 0.8774.. Test accuracy: 0.7336.. 0.2535 s/batch
# Epoch: 4/5.. Loss: 0.8806.. Test accuracy: 0.7004.. 0.3289 s/batch
# Epoch: 4/5.. Loss: 0.8997.. Test accuracy: 0.7250.. 0.2557 s/batch
# Epoch: 4/5.. Loss: 0.8816.. Test accuracy: 0.7287.. 0.3202 s/batch
# Epoch: 4/5.. Loss: 0.8744.. Test accuracy: 0.7109.. 0.2549 s/batch
# Epoch: 4/5.. Loss: 0.9318.. Test accuracy: 0.7348.. 0.3108 s/batch
# Epoch: 4/5.. Loss: 0.8673.. Test accuracy: 0.7086.. 0.2548 s/batch
# Epoch: 4/5.. Loss: 0.8964.. Test accuracy: 0.7670.. 0.2868 s/batch
# Epoch: 4/5.. Loss: 0.9426.. Test accuracy: 0.6703.. 0.2788 s/batch
# Epoch: 4/5.. Loss: 0.8612.. Test accuracy: 0.7406.. 0.2658 s/batch
# Epoch: 4/5.. Loss: 0.8429.. Test accuracy: 0.6883.. 0.2968 s/batch
# Epoch: 4/5.. Loss: 0.8572.. Test accuracy: 0.7303.. 0.2520 s/batch
# Epoch: 4/5.. Loss: 0.9295.. Test accuracy: 0.7129.. 0.3035 s/batch
# Epoch: 4/5.. Loss: 0.8607.. Test accuracy: 0.7207.. 0.2523 s/batch
# Epoch: 4/5.. Loss: 0.8777.. Test accuracy: 0.7285.. 0.3170 s/batch
# Epoch: 4/5.. Loss: 0.8669.. Test accuracy: 0.7113.. 0.2558 s/batch
# Epoch: 4/5.. Loss: 0.8567.. Test accuracy: 0.7164.. 0.3246 s/batch
# Epoch: 4/5.. Loss: 0.8241.. Test accuracy: 0.7346.. 0.2479 s/batch
# Epoch: 4/5.. Loss: 0.8680.. Test accuracy: 0.7502.. 0.3343 s/batch
# Epoch: 4/5.. Loss: 0.9330.. Test accuracy: 0.7201.. 0.2548 s/batch
# Epoch: 4/5.. Loss: 0.8560.. Test accuracy: 0.7369.. 0.3377 s/batch
# Epoch: 4/5.. Loss: 0.8601.. Test accuracy: 0.7238.. 0.2519 s/batch
# Epoch: 4/5.. Loss: 0.7966.. Test accuracy: 0.7557.. 0.3256 s/batch
# Epoch: 4/5.. Loss: 0.8463.. Test accuracy: 0.7166.. 0.2509 s/batch
# Epoch: 4/5.. Loss: 0.8347.. Test accuracy: 0.7551.. 0.3256 s/batch
# Epoch: 4/5.. Loss: 0.8385.. Test accuracy: 0.7715.. 0.2519 s/batch
# Epoch: 4/5.. Loss: 0.8719.. Test accuracy: 0.7441.. 0.3176 s/batch
# Epoch: 4/5.. Loss: 0.8388.. Test accuracy: 0.7494.. 0.2552 s/batch
# Epoch: 4/5.. Loss: 0.8121.. Test accuracy: 0.7021.. 0.3081 s/batch
# Epoch: 4/5.. Loss: 0.8557.. Test accuracy: 0.7066.. 0.2433 s/batch
# Epoch: 5/5.. Loss: 0.8582.. Test accuracy: 0.7389.. 0.2528 s/batch
# Epoch: 5/5.. Loss: 0.7781.. Test accuracy: 0.7543.. 0.2706 s/batch
# Epoch: 5/5.. Loss: 0.8019.. Test accuracy: 0.7418.. 0.2730 s/batch
# Epoch: 5/5.. Loss: 0.7913.. Test accuracy: 0.7541.. 0.2749 s/batch
# Epoch: 5/5.. Loss: 0.7889.. Test accuracy: 0.7090.. 0.2561 s/batch
# Epoch: 5/5.. Loss: 0.9232.. Test accuracy: 0.7455.. 0.2789 s/batch
# Epoch: 5/5.. Loss: 0.8528.. Test accuracy: 0.7611.. 0.2486 s/batch
# Epoch: 5/5.. Loss: 0.7942.. Test accuracy: 0.7650.. 0.2843 s/batch
# Epoch: 5/5.. Loss: 0.8655.. Test accuracy: 0.7697.. 0.2447 s/batch
# Epoch: 5/5.. Loss: 0.8324.. Test accuracy: 0.7504.. 0.2996 s/batch
# Epoch: 5/5.. Loss: 0.8216.. Test accuracy: 0.7674.. 0.2535 s/batch
# Epoch: 5/5.. Loss: 0.7762.. Test accuracy: 0.7572.. 0.3032 s/batch
# Epoch: 5/5.. Loss: 0.8178.. Test accuracy: 0.7539.. 0.2493 s/batch
# Epoch: 5/5.. Loss: 0.7551.. Test accuracy: 0.7453.. 0.3124 s/batch
# Epoch: 5/5.. Loss: 0.8175.. Test accuracy: 0.7566.. 0.2458 s/batch
# Epoch: 5/5.. Loss: 0.8291.. Test accuracy: 0.7555.. 0.3195 s/batch
# Epoch: 5/5.. Loss: 0.8005.. Test accuracy: 0.7822.. 0.2456 s/batch
# Epoch: 5/5.. Loss: 0.8023.. Test accuracy: 0.7492.. 0.3189 s/batch
# Epoch: 5/5.. Loss: 0.8247.. Test accuracy: 0.7563.. 0.2492 s/batch
# Epoch: 5/5.. Loss: 0.7565.. Test accuracy: 0.7437.. 0.3245 s/batch
# Epoch: 5/5.. Loss: 0.7746.. Test accuracy: 0.7529.. 0.2483 s/batch
# Epoch: 5/5.. Loss: 0.8493.. Test accuracy: 0.7426.. 0.3238 s/batch
# Epoch: 5/5.. Loss: 0.7919.. Test accuracy: 0.7426.. 0.2525 s/batch
# Epoch: 5/5.. Loss: 0.8136.. Test accuracy: 0.7877.. 0.3215 s/batch
# Epoch: 5/5.. Loss: 0.7744.. Test accuracy: 0.7590.. 0.2523 s/batch
# Epoch: 5/5.. Loss: 0.8243.. Test accuracy: 0.7789.. 0.3245 s/batch
# Epoch: 5/5.. Loss: 0.8206.. Test accuracy: 0.8002.. 0.2479 s/batch
# Epoch: 5/5.. Loss: 0.7645.. Test accuracy: 0.7707.. 0.3150 s/batch
# Epoch: 5/5.. Loss: 0.7589.. Test accuracy: 0.7809.. 0.2500 s/batch
# Epoch: 5/5.. Loss: 0.7389.. Test accuracy: 0.7760.. 0.3123 s/batch
# Epoch: 5/5.. Loss: 0.8458.. Test accuracy: 0.7545.. 0.2552 s/batch
# Epoch: 5/5.. Loss: 0.8160.. Test accuracy: 0.7863.. 0.2970 s/batch
# Epoch: 5/5.. Loss: 0.8020.. Test accuracy: 0.7777.. 0.2466 s/batch
# Epoch: 5/5.. Loss: 0.7644.. Test accuracy: 0.7633.. 0.2931 s/batch
# Epoch: 5/5.. Loss: 0.7603.. Test accuracy: 0.7771.. 0.2508 s/batch
# Epoch: 5/5.. Loss: 0.7502.. Test accuracy: 0.7697.. 0.2886 s/batch
# Epoch: 5/5.. Loss: 0.7717.. Test accuracy: 0.7496.. 0.2502 s/batch
# Epoch: 5/5.. Loss: 0.8210.. Test accuracy: 0.7732.. 0.2846 s/batch

# %% [markdown]
# Save best trained model.

# %%
## You should be familiar with how to save a pytorch model (Make sure to save the model in your Drive)

torch.save(net.state_dict(), '/content/drive/MyDrive/Colab Notebooks/model.pth')

# %% [markdown]
# # Some visualisations and Interpretation questions
# This code allows us to look at the filters of the first layer of convolution :

# %%
def visualize_filters(layer, title='Filters'):
    filters = layer.weight.data.clone().cpu()
    filters = (filters - filters.min()) / (filters.max() - filters.min())
    grid = vutils.make_grid(filters, nrow=8, padding=2)
    plt.figure(figsize=(8,8))
    plt.imshow(grid.permute(1, 2, 0))
    plt.title(title)
    plt.axis('off')
    plt.show()

model = ConvNet() # Untrained model

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# --- Untrained filters ---
# "features[0]" is your first convolutionnal layer, you might have to change it to conv1 if it was the name you gave it to
filters_untrained = model.features[0].weight.data.clone().cpu()
filters_untrained = (filters_untrained - filters_untrained.min()) / (filters_untrained.max() - filters_untrained.min())
grid_untrained = vutils.make_grid(filters_untrained, nrow=8, padding=2)
axes[0].imshow(grid_untrained.permute(1, 2, 0))
axes[0].set_title("Block 1 - First Conv Filters (Untrained)")
axes[0].axis("off")

# --- Trained filters ---
# Same thing here
filters_trained = net.features[0].weight.data.clone().cpu()
filters_trained = (filters_trained - filters_trained.min()) / (filters_trained.max() - filters_trained.min())
grid_trained = vutils.make_grid(filters_trained, nrow=8, padding=2)
axes[1].imshow(grid_trained.permute(1, 2, 0))
axes[1].set_title("Block 1 - First Conv Filters (Trained)")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What do you notice about the filters after the training ? Try to fin an interpretation about it.

# %% [markdown]
# On the left, untrained filters look random and noisy. On the right, the trained filters remain visually noisy, but they are no longer random. They have learned to capture useful low-level features like edges and color contrasts. Due to their small size (3×3) and multi-channel nature, they are not easily interpretable, but when combined across layers they enable good performance.

# %% [markdown]
# ### Activation maps
# This code snippet uses a forward hook to capture the output of the first convolutional layer of a CNN when a sample image is passed through it. The resulting activation maps show how each filter in the layer responds to different regions or features in the image.

# %%
def get_activation(model, layer, x):
    activation = {}
    def hook_fn(module, input, output):
        activation['output'] = output.detach().cpu()
    hook = layer.register_forward_hook(hook_fn)
    model(x)
    hook.remove()
    return activation['output']

data_iter = iter(trainloader)
sample_images, sample_labels = next(data_iter)
sample_img = sample_images[14].unsqueeze(0)

# Get the feature maps after the first convolution (for example)
activation = get_activation(net, net.features[0], sample_img)

# Visualize a few feature maps in RGB:
def plot_feature_maps(feature_maps, n_cols=8):
    n_features = feature_maps.shape[1]
    n_rows = (n_features + n_cols - 1) // n_cols
    plt.figure(figsize=(n_cols * 1.5, n_rows * 1.5))
    for i in range(n_features):
        plt.subplot(n_rows, n_cols, i + 1)
        # Extract the i-th feature map from the first (and only) sample in the batch
        act = feature_maps[0, i, :, :]
        # Normalize the activation map to [0, 1]
        act_norm = (act - act.min()) / (act.max() - act.min() + 1e-8)
        # Repeat the single channel 3 times to form an RGB image
        act_rgb = act_norm.unsqueeze(0).repeat(3, 1, 1)
        plt.imshow(act_rgb.permute(1, 2, 0))
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_feature_maps(activation, n_cols=8)

# Play with the index of the chosen sample to notice more patterns and answer the question

# %% [markdown]
# ### 1. Feature Detection
# What specific features do you observe in these activation maps? Do some maps clearly highlight edges, contours, or textures? How might these features relate to the overall structure of the sample (e.g., the outline of a horse)?
#
# ---
#
# In these activation maps, structured patterns appear, which indicates that the convolutional filters are detecting visual features from the image. Some activations show strong intensity transitions. These correspond to edge detectors. Second, we can observe than some maps show the global silhouette of the horse, there's a big contrast between the horse and the background. These correspond to contours detectors. Lastly, we can see local variations on some maps, different brightness next to each other. These are linked to the texture detectors.
#
# Overall, different filters specialize in detecting different visual features (edges, orientations, shapes). When combined across many filters, they represent the full structure of the object.
#
# ### 2. Effect of Training
# Consider how the activations might change after training versus an untrained (random) network. What does this tell you about the learning process?
#
# In an untrained network, the filters are initialized randomly. As a result, activation maps look noisy and no object structure appears. After training, the filters detect horizontal edges and contours or shapes. This happens because backpropagation updates the convolutional filters to minimize error. Over time, the network learns filters that capture the most useful visual features for distinguishing classes in datasets such as CIFAR-10.
