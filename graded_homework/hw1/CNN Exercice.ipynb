# %% [markdown]
# ## Convolutional Networks
#
# We'll check out how to build a **convolutional network** to classify CIFAR10 images. By using weight sharing - multiple units with the same weights - convolutional layers are able to learn repeated patterns in your data. For example, a unit could learn the pattern for an eye, or a face, or lower level features like edges.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F
import torch.utils.data as utils
from torchvision import datasets, transforms
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
import torchvision.utils as vutils
from torchvision.datasets import CIFAR10

# %matplotlib inline

# %%
label_names = [
    'airplane',
    'automobile',
    'bird',
    'cat',
    'deer',
    'dog',
    'frog',
    'horse',
    'ship',
    'truck'
]


def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

# %%
def get_train_valid_loader(data_dir='data',
                           batch_size=64,
                           augment=False,
                           random_seed=1,
                           valid_size=0.02,
                           shuffle=True,
                           show_sample=True,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms for validation (no augmentation)
    valid_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # Define the transform for training (and data augmentation)

    train_transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images if requested
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = next(data_iter)
        # Unnormalize the images for display
        mean = [0.4914, 0.4822, 0.4465]
        std = [0.2023, 0.1994, 0.2010]
        unnorm_images = [unnormalize(img, mean, std) for img in images]
        X = torch.stack(unnorm_images).numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    return (train_loader, valid_loader)

def unnormalize(img, mean, std):
    img = img * torch.tensor(std).view(3, 1, 1) + torch.tensor(mean).view(3, 1, 1)
    return img

trainloader, valloader = get_train_valid_loader()
# Out:
# 100%|██████████| 170M/170M [00:04<00:00, 38.4MB/s]
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:424: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:432: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   self.check_worker_number_rationality()
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.9843137].

# %% [markdown]
# # Convolutional Neural Network Architecture

# %% [markdown]
# Let's first talk about the overall architecture of a CNN and how each dimension evolves after each layer, we'll take as example the first and famous CNN LeNet5 :
# <figure align="center">
#   <img src="https://doimages.nyc3.cdn.digitaloceanspaces.com/010AI-ML/content/images/2021/10/image-17.png" alt="LeNet5 Architecture" width="600">
#   <figcaption>Image credit: <a href="https://en.wikipedia.org">Wikipedia</a></figcaption>
# </figure>

# %% [markdown]
# For that, we will have some quick questions to see if you understand what happens during training/inference:
#
# ### 1. First Layer Convolution
#
# If we consider the input of LeNet5 to be CIFAR-10, what would be the shape of the parameters of the first convolutional layer (stride = 1)?
#
# - **A.** `torch.Size([6, 1, 5, 5])`
# - **B.** `torch.Size([6, 3, 3, 3])`
# - **C.** `torch.Size([6, 1, 5, 5])`
# - **D.** `torch.Size([6, 3, 5, 5])`
#
# ---
#
# Response D., as we have 6 filters of size 5x5 (for the kernel) and the number 3 is for the number of input channels (3 because CIFAR-10 contains RGB images).
#
# ### 2. Subsampling Window
#
# What is the shape of the subsampling window (stride = 2) for the second layer (between C1 and C2), and does this shape remain invariant regardless of the subsampling method (e.g., Avg pooling or Max pooling)?
#
# - **A.** `2x2, yes it does`
# - **B.** `3x3, no it doesn't`
# - **C.** `2x2, no it doesn't`
# - **D.** `yes, it does`
#
# ---
#
# Response A., because we're going from 28x28 to 14x14 so subsampling window is 2x2 and the shape doesn't change between Avg pooling or Max pooling. They only differ in how the value is computed inside the window.
#
# ### 3. Backpropagation for Convolutional Filters
#
# Do the filters in the convolutional layers also benefit from backpropagation?
#
# ---
#
# Yes, The filters in convolutional layers are trainable parameters, so they are updated through backpropagation during training.
#
# ### 4. Role of the Fully-Connected Layer
#
# Explain in your own words why it is necessary to have a fully-connected layer in the architecture.
#
# ---
# Fully-conected layer is used to combine extracted features from the convolutional layers and perform classification.
#
# If you had any struggle to answer one of theses questions, feel free to ask a TA about intuition or hints about the solution.

# %% [markdown]
# # Build your own Convolutional Neural Network Architecture

# %% [markdown]
# ## Different ways to improve the accuracy of your network :
# - Change the number of convolutions and layers (you can take inspiration from internet as you as you cite the architecture)
# - Change the optmizer / its hyperparameters
# - Add new types of layers
# - Do some data augmentation in the get_train_valid_loader function (flipped, cropped, uncentered images) cf. https://pytorch.org/vision/stable/transforms.html

# %%
class ConvNet(nn.Module):
    def __init__(self, n_input_channels=3, n_output=10):
        super().__init__()
        ################################################################################
        # TODO:                                                                        #
        # Define 2 or more different layers of the neural network                      #
        ################################################################################

        # Convolutional feature extractor
        self.features = nn.Sequential(
            nn.Conv2d(n_input_channels, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(2,2),

            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2,2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2,2)
        )

        # Classifier
        self.classifier = nn.Sequential(
            nn.Linear(128 * 4 * 4, 256),  # assuming input images are 32x32
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, n_output)
        )

        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

    def forward(self, x):
        ################################################################################
        # TODO:                                                                        #
        # Set up the forward pass that the input data will go through.                 #
        # A good activation function betweent the layers is a ReLu function.           #
        #                                                                              #
        # Note that the output of the last convolution layer should be flattened       #
        # before being inputted to the fully connected layer. We can flatten           #
        # Tensor `x` with `x.view`.                                                    #
        ################################################################################
        x = self.features(x)

        # flatten
        x = x.view(x.size(0), -1)

        x = self.classifier(x)

        return x
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        return x

    def predict(self, x):
        logits = self.forward(x)
        return F.softmax(logits)

# %%
net = ConvNet()
################################################################################
# TODO:                                                                        #
# Choose an Optimizer that will be used to minimize the loss function.         #
# Choose a critera that measures the loss                                      #
################################################################################
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

epochs = 3
steps = 0
running_loss = 0
print_every = 20
for e in range(epochs):
    start = time.time()
    for images, labels in iter(trainloader):

        steps += 1
        if steps == 1:
          mean = [0.4914, 0.4822, 0.4465]
          std = [0.2023, 0.1994, 0.2010]
          unnorm_images = [unnormalize(img, mean, std) for img in images]
          X = torch.stack(unnorm_images).numpy().transpose([0, 2, 3, 1])
          plot_images(X, labels)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        #                                                                              #
        ################################################################################
        optimizer.zero_grad()

        output = net(images)
        targets = labels
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        loss = criterion(output, targets)
        ################################################################################
        # TODO:                                                                        #
        # Run the training process                                                     #
        #                                                                              #
        # HINT: Calculate the gradient and move one step further                       #
        ################################################################################
        loss.backward()
        optimizer.step()
        ################################################################################
        #                              END OF YOUR CODE                                #
        ################################################################################

        running_loss += loss.item()

        if steps % print_every == 0:
            stop = time.time()
            # Test accuracy
            accuracy = 0
            for ii, (images, labels) in enumerate(valloader):

                ################################################################################
                # TODO:                                                                        #
                # Calculate the accuracy                                                       #
                ################################################################################
                outputs = net(images)
                _, predicted = torch.max(outputs, 1)

                accuracy += (predicted == labels).float().mean()
                ################################################################################
                #                              END OF YOUR CODE                                #
                ################################################################################

            print("Epoch: {}/{}..".format(e+1, epochs),
                  "Loss: {:.4f}..".format(running_loss/print_every),
                  "Test accuracy: {:.4f}..".format(accuracy/(ii+1)),
                  "{:.4f} s/batch".format((stop - start)/print_every)
                 )
            running_loss = 0
            start = time.time()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..1.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-2.9802322e-08..0.92941177].
# Epoch: 1/3.. Loss: 2.1773.. Test accuracy: 0.3178.. 0.1635 s/batch
# Epoch: 1/3.. Loss: 1.8608.. Test accuracy: 0.3340.. 0.1094 s/batch
# Epoch: 1/3.. Loss: 1.7511.. Test accuracy: 0.3691.. 0.1094 s/batch
# Epoch: 1/3.. Loss: 1.6857.. Test accuracy: 0.4016.. 0.1448 s/batch
# Epoch: 1/3.. Loss: 1.5899.. Test accuracy: 0.3922.. 0.1088 s/batch
# Epoch: 1/3.. Loss: 1.6000.. Test accuracy: 0.4211.. 0.1084 s/batch
# Epoch: 1/3.. Loss: 1.5594.. Test accuracy: 0.4566.. 0.1192 s/batch
# Epoch: 1/3.. Loss: 1.4883.. Test accuracy: 0.4111.. 0.1409 s/batch
# Epoch: 1/3.. Loss: 1.5108.. Test accuracy: 0.4709.. 0.1083 s/batch
# Epoch: 1/3.. Loss: 1.4567.. Test accuracy: 0.4510.. 0.1071 s/batch
# Epoch: 1/3.. Loss: 1.4580.. Test accuracy: 0.4488.. 0.1258 s/batch
# Epoch: 1/3.. Loss: 1.4639.. Test accuracy: 0.4855.. 0.1309 s/batch
# Epoch: 1/3.. Loss: 1.4588.. Test accuracy: 0.4912.. 0.1084 s/batch
# Epoch: 1/3.. Loss: 1.4606.. Test accuracy: 0.4957.. 0.1080 s/batch
# Epoch: 1/3.. Loss: 1.3830.. Test accuracy: 0.5020.. 0.1444 s/batch
# Epoch: 1/3.. Loss: 1.3719.. Test accuracy: 0.4797.. 0.1166 s/batch
# Epoch: 1/3.. Loss: 1.3449.. Test accuracy: 0.5037.. 0.1070 s/batch
# Epoch: 1/3.. Loss: 1.3324.. Test accuracy: 0.5111.. 0.1091 s/batch
# Epoch: 1/3.. Loss: 1.3773.. Test accuracy: 0.5404.. 0.1479 s/batch
# Epoch: 1/3.. Loss: 1.3647.. Test accuracy: 0.5365.. 0.1068 s/batch
# Epoch: 1/3.. Loss: 1.3192.. Test accuracy: 0.5402.. 0.1085 s/batch
# Epoch: 1/3.. Loss: 1.2924.. Test accuracy: 0.5230.. 0.1058 s/batch
# Epoch: 1/3.. Loss: 1.3113.. Test accuracy: 0.5518.. 0.1489 s/batch
# Epoch: 1/3.. Loss: 1.2617.. Test accuracy: 0.5539.. 0.1085 s/batch
# Epoch: 1/3.. Loss: 1.2224.. Test accuracy: 0.5494.. 0.1075 s/batch
# Epoch: 1/3.. Loss: 1.2748.. Test accuracy: 0.5533.. 0.1040 s/batch
# Epoch: 1/3.. Loss: 1.2658.. Test accuracy: 0.5678.. 0.1544 s/batch
# Epoch: 1/3.. Loss: 1.2675.. Test accuracy: 0.5484.. 0.1064 s/batch
# Epoch: 1/3.. Loss: 1.2472.. Test accuracy: 0.5654.. 0.1064 s/batch
# Epoch: 1/3.. Loss: 1.2274.. Test accuracy: 0.5574.. 0.1073 s/batch
# Epoch: 1/3.. Loss: 1.2021.. Test accuracy: 0.5459.. 0.1563 s/batch
# Epoch: 1/3.. Loss: 1.2362.. Test accuracy: 0.5719.. 0.1056 s/batch
# Epoch: 1/3.. Loss: 1.2113.. Test accuracy: 0.5744.. 0.1081 s/batch
# Epoch: 1/3.. Loss: 1.1492.. Test accuracy: 0.5865.. 0.1124 s/batch
# Epoch: 1/3.. Loss: 1.1688.. Test accuracy: 0.5830.. 0.1446 s/batch
# Epoch: 1/3.. Loss: 1.2232.. Test accuracy: 0.5988.. 0.1096 s/batch
# Epoch: 1/3.. Loss: 1.1412.. Test accuracy: 0.6043.. 0.1106 s/batch
# Epoch: 1/3.. Loss: 1.1866.. Test accuracy: 0.5814.. 0.1317 s/batch
# Epoch: 2/3.. Loss: 1.1772.. Test accuracy: 0.5621.. 0.0991 s/batch
# Epoch: 2/3.. Loss: 1.0994.. Test accuracy: 0.5932.. 0.1122 s/batch
# Epoch: 2/3.. Loss: 1.0949.. Test accuracy: 0.6168.. 0.1129 s/batch
# Epoch: 2/3.. Loss: 1.0789.. Test accuracy: 0.6061.. 0.1625 s/batch
# Epoch: 2/3.. Loss: 1.1259.. Test accuracy: 0.5801.. 0.1147 s/batch
# Epoch: 2/3.. Loss: 1.1211.. Test accuracy: 0.6207.. 0.1105 s/batch
# Epoch: 2/3.. Loss: 1.0763.. Test accuracy: 0.6338.. 0.1097 s/batch
# Epoch: 2/3.. Loss: 1.1042.. Test accuracy: 0.5945.. 0.1569 s/batch
# Epoch: 2/3.. Loss: 1.1120.. Test accuracy: 0.6105.. 0.1099 s/batch
# Epoch: 2/3.. Loss: 1.0785.. Test accuracy: 0.6307.. 0.1105 s/batch
# Epoch: 2/3.. Loss: 1.0602.. Test accuracy: 0.6080.. 0.1141 s/batch
# Epoch: 2/3.. Loss: 1.0696.. Test accuracy: 0.6055.. 0.1501 s/batch
# Epoch: 2/3.. Loss: 1.0819.. Test accuracy: 0.6242.. 0.1129 s/batch
# Epoch: 2/3.. Loss: 1.1197.. Test accuracy: 0.6072.. 0.1094 s/batch
# Epoch: 2/3.. Loss: 1.1050.. Test accuracy: 0.6338.. 0.1283 s/batch
# Epoch: 2/3.. Loss: 1.0526.. Test accuracy: 0.6264.. 0.1369 s/batch
# Epoch: 2/3.. Loss: 1.0559.. Test accuracy: 0.6148.. 0.1168 s/batch
# Epoch: 2/3.. Loss: 1.0391.. Test accuracy: 0.6088.. 0.1108 s/batch
# Epoch: 2/3.. Loss: 1.1032.. Test accuracy: 0.6205.. 0.1381 s/batch
# Epoch: 2/3.. Loss: 1.0635.. Test accuracy: 0.6264.. 0.1199 s/batch
# Epoch: 2/3.. Loss: 1.0450.. Test accuracy: 0.6467.. 0.1078 s/batch
# Epoch: 2/3.. Loss: 1.0585.. Test accuracy: 0.6150.. 0.1090 s/batch
# Epoch: 2/3.. Loss: 1.0856.. Test accuracy: 0.6166.. 0.1473 s/batch
# Epoch: 2/3.. Loss: 1.0726.. Test accuracy: 0.6357.. 0.1110 s/batch
# Epoch: 2/3.. Loss: 1.0105.. Test accuracy: 0.6344.. 0.1142 s/batch
# Epoch: 2/3.. Loss: 1.0570.. Test accuracy: 0.6424.. 0.1126 s/batch
# Epoch: 2/3.. Loss: 1.0258.. Test accuracy: 0.6498.. 0.1582 s/batch
# Epoch: 2/3.. Loss: 1.0135.. Test accuracy: 0.6471.. 0.1130 s/batch
# Epoch: 2/3.. Loss: 0.9838.. Test accuracy: 0.6465.. 0.1102 s/batch
# Epoch: 2/3.. Loss: 0.9639.. Test accuracy: 0.6455.. 0.1100 s/batch
# Epoch: 2/3.. Loss: 1.0167.. Test accuracy: 0.6572.. 0.1530 s/batch
# Epoch: 2/3.. Loss: 0.9880.. Test accuracy: 0.6662.. 0.1103 s/batch
# Epoch: 2/3.. Loss: 1.0041.. Test accuracy: 0.6553.. 0.1115 s/batch
# Epoch: 2/3.. Loss: 0.9518.. Test accuracy: 0.6600.. 0.1238 s/batch
# Epoch: 2/3.. Loss: 1.0121.. Test accuracy: 0.6141.. 0.1401 s/batch
# Epoch: 2/3.. Loss: 1.0243.. Test accuracy: 0.6436.. 0.1121 s/batch
# Epoch: 2/3.. Loss: 0.9922.. Test accuracy: 0.6662.. 0.1096 s/batch
# Epoch: 2/3.. Loss: 1.0321.. Test accuracy: 0.6479.. 0.1342 s/batch
# Epoch: 3/3.. Loss: 0.9935.. Test accuracy: 0.6359.. 0.0569 s/batch
# Epoch: 3/3.. Loss: 0.9300.. Test accuracy: 0.6467.. 0.1144 s/batch
# Epoch: 3/3.. Loss: 0.9475.. Test accuracy: 0.6611.. 0.1102 s/batch
# Epoch: 3/3.. Loss: 0.9115.. Test accuracy: 0.6615.. 0.1571 s/batch
# Epoch: 3/3.. Loss: 0.9241.. Test accuracy: 0.6416.. 0.1183 s/batch
# Epoch: 3/3.. Loss: 0.9465.. Test accuracy: 0.6564.. 0.1109 s/batch
# Epoch: 3/3.. Loss: 0.9361.. Test accuracy: 0.6730.. 0.1101 s/batch
# Epoch: 3/3.. Loss: 0.9447.. Test accuracy: 0.6602.. 0.1551 s/batch
# Epoch: 3/3.. Loss: 0.8932.. Test accuracy: 0.6600.. 0.1117 s/batch
# Epoch: 3/3.. Loss: 0.9537.. Test accuracy: 0.6543.. 0.1089 s/batch
# Epoch: 3/3.. Loss: 0.9988.. Test accuracy: 0.6551.. 0.1188 s/batch
# Epoch: 3/3.. Loss: 0.9141.. Test accuracy: 0.6568.. 0.1430 s/batch
# Epoch: 3/3.. Loss: 0.9439.. Test accuracy: 0.6711.. 0.2106 s/batch
# Epoch: 3/3.. Loss: 0.8680.. Test accuracy: 0.6576.. 0.1123 s/batch
# Epoch: 3/3.. Loss: 0.8919.. Test accuracy: 0.6479.. 0.1507 s/batch
# Epoch: 3/3.. Loss: 0.9301.. Test accuracy: 0.6607.. 0.1107 s/batch
# Epoch: 3/3.. Loss: 0.9454.. Test accuracy: 0.6768.. 0.1102 s/batch
# Epoch: 3/3.. Loss: 0.9701.. Test accuracy: 0.6639.. 0.1276 s/batch
# Epoch: 3/3.. Loss: 0.9350.. Test accuracy: 0.6447.. 0.1363 s/batch
# Epoch: 3/3.. Loss: 0.9143.. Test accuracy: 0.6514.. 0.1119 s/batch
# Epoch: 3/3.. Loss: 0.9680.. Test accuracy: 0.6693.. 0.1128 s/batch
# Epoch: 3/3.. Loss: 0.8878.. Test accuracy: 0.6723.. 0.1510 s/batch
# Epoch: 3/3.. Loss: 0.8908.. Test accuracy: 0.6871.. 0.1111 s/batch
# Epoch: 3/3.. Loss: 0.9232.. Test accuracy: 0.6664.. 0.1090 s/batch
# Epoch: 3/3.. Loss: 0.9264.. Test accuracy: 0.6791.. 0.1125 s/batch
# Epoch: 3/3.. Loss: 0.9078.. Test accuracy: 0.6773.. 0.1583 s/batch
# Epoch: 3/3.. Loss: 0.8788.. Test accuracy: 0.6611.. 0.1096 s/batch
# Epoch: 3/3.. Loss: 0.9979.. Test accuracy: 0.6584.. 0.1144 s/batch
# Epoch: 3/3.. Loss: 0.9181.. Test accuracy: 0.6785.. 0.1231 s/batch
# Epoch: 3/3.. Loss: 0.8938.. Test accuracy: 0.6672.. 0.1406 s/batch
# Epoch: 3/3.. Loss: 0.8693.. Test accuracy: 0.6602.. 0.1145 s/batch
# Epoch: 3/3.. Loss: 0.9012.. Test accuracy: 0.6824.. 0.1114 s/batch
# Epoch: 3/3.. Loss: 0.9431.. Test accuracy: 0.6953.. 0.1363 s/batch
# Epoch: 3/3.. Loss: 0.8980.. Test accuracy: 0.6715.. 0.1215 s/batch
# Epoch: 3/3.. Loss: 0.8810.. Test accuracy: 0.6738.. 0.1095 s/batch
# Epoch: 3/3.. Loss: 0.9113.. Test accuracy: 0.6770.. 0.1114 s/batch
# Epoch: 3/3.. Loss: 0.8835.. Test accuracy: 0.6859.. 0.1572 s/batch
# Epoch: 3/3.. Loss: 0.9140.. Test accuracy: 0.6598.. 0.1102 s/batch

# %% [markdown]
# Save best trained model.

# %%
## You should be familiar with how to save a pytorch model (Make sure to save the model in your Drive)

torch.save(net.state_dict(), '/content/drive/MyDrive/Colab Notebooks/model.pth')

# %% [markdown]
# # Some visualisations and Interpretation questions
# This code allows us to look at the filters of the first layer of convolution :

# %%
def visualize_filters(layer, title='Filters'):
    filters = layer.weight.data.clone().cpu()
    filters = (filters - filters.min()) / (filters.max() - filters.min())
    grid = vutils.make_grid(filters, nrow=8, padding=2)
    plt.figure(figsize=(8,8))
    plt.imshow(grid.permute(1, 2, 0))
    plt.title(title)
    plt.axis('off')
    plt.show()

model = ConvNet() # Untrained model

fig, axes = plt.subplots(1, 2, figsize=(16, 8))

# --- Untrained filters ---
# "features[0]" is your first convolutionnal layer, you might have to change it to conv1 if it was the name you gave it to
filters_untrained = model.features[0].weight.data.clone().cpu()
filters_untrained = (filters_untrained - filters_untrained.min()) / (filters_untrained.max() - filters_untrained.min())
grid_untrained = vutils.make_grid(filters_untrained, nrow=8, padding=2)
axes[0].imshow(grid_untrained.permute(1, 2, 0))
axes[0].set_title("Block 1 - First Conv Filters (Untrained)")
axes[0].axis("off")

# --- Trained filters ---
# Same thing here
filters_trained = net.features[0].weight.data.clone().cpu()
filters_trained = (filters_trained - filters_trained.min()) / (filters_trained.max() - filters_trained.min())
grid_trained = vutils.make_grid(filters_trained, nrow=8, padding=2)
axes[1].imshow(grid_trained.permute(1, 2, 0))
axes[1].set_title("Block 1 - First Conv Filters (Trained)")
axes[1].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### What do you notice about the filters after the training ? Try to fin an interpretation about it.

# %% [markdown]
# On the left, we can see that the filters look random and noisy. There's no clear structure. On the right, after the training, the filters look more organized, some have dominant color channels, are more structured. The first layer of convolution detect color. It emphazise a specific RGB channel.

# %% [markdown]
# ### Activation maps
# This code snippet uses a forward hook to capture the output of the first convolutional layer of a CNN when a sample image is passed through it. The resulting activation maps show how each filter in the layer responds to different regions or features in the image.

# %%
def get_activation(model, layer, x):
    activation = {}
    def hook_fn(module, input, output):
        activation['output'] = output.detach().cpu()
    hook = layer.register_forward_hook(hook_fn)
    model(x)
    hook.remove()
    return activation['output']

data_iter = iter(trainloader)
sample_images, sample_labels = next(data_iter)
sample_img = sample_images[14].unsqueeze(0)

# Get the feature maps after the first convolution (for example)
activation = get_activation(net, net.features[0], sample_img)

# Visualize a few feature maps in RGB:
def plot_feature_maps(feature_maps, n_cols=8):
    n_features = feature_maps.shape[1]
    n_rows = (n_features + n_cols - 1) // n_cols
    plt.figure(figsize=(n_cols * 1.5, n_rows * 1.5))
    for i in range(n_features):
        plt.subplot(n_rows, n_cols, i + 1)
        # Extract the i-th feature map from the first (and only) sample in the batch
        act = feature_maps[0, i, :, :]
        # Normalize the activation map to [0, 1]
        act_norm = (act - act.min()) / (act.max() - act.min() + 1e-8)
        # Repeat the single channel 3 times to form an RGB image
        act_rgb = act_norm.unsqueeze(0).repeat(3, 1, 1)
        plt.imshow(act_rgb.permute(1, 2, 0))
        plt.axis('off')
    plt.tight_layout()
    plt.show()

plot_feature_maps(activation, n_cols=8)

# Play with the index of the chosen sample to notice more patterns and answer the question

# %% [markdown]
# ### 1. Feature Detection
# What specific features do you observe in these activation maps? Do some maps clearly highlight edges, contours, or textures? How might these features relate to the overall structure of the sample (e.g., the outline of a horse)?
#
# ---
#
# In these activation maps, structured patterns appear, which indicates that the convolutional filters are detecting visual features from the image. Some activations show strong intensity transitions. These correspond to edge detectors. Second, we can observe than some maps show the global silhouette of the horse, there's a big contrast between the horse and the background. These correspond to contours detectors. Lastly, we can see local variations on some maps, different brightness next to each other. These are linked to the texture detectors.
#
# Overall, different filters specialize in detecting different visual features (edges, orientations, shapes). When combined across many filters, they represent the full structure of the object.
#
# ### 2. Effect of Training
# Consider how the activations might change after training versus an untrained (random) network. What does this tell you about the learning process?
